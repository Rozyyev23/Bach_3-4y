# %% [markdown]
# <!-- авававава -->

# %% [markdown]
# Методы оценки параметров нелинейных моделей: методы, основанные на линейной аппроксимации модели
#
#
# Регрессии нелинейные относительно включенных в анализ переменных, но линейные по оцениваемым параметрам
# Например, y=b_0-b_1*1/x_i  +e_i – кривая Энгеля, где х - доходы, у – расходы на непродовольственные товары
# Оценка: используется подход, именуемый «замена переменных». Суть его состоит в замене «нелинейных» объясняющих переменных новыми «линейными» переменными и сведение нелинейной регрессии к линейной. К новой «преобразованной» регрессии может быть применен обычный метод наименьших квадратов (МНК)
#
# ![image.png](data:image/png;base64,...)
#
# Еще из интернета:
#
# 1)
#
# ![image.png](data:image/png;base64,...)
#
# Формируется итеративная процедура последовательного приближения к искомым “оптимальным” оценкам ai, которым соответствует локальный оптимум суммы квадратов ошибки в некоторой области существования значений параметров модели
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 38.	МВНК: дисперсии отклонений неизвестны
#
#
# Для повышения качества моделей используют Взвешенный Метод Наименьших Квадратов.
#
#
# Суть: смягчаем гетероскедастичность путем деления каждого наблюдаемого значения на соответствующее значение дисперсии случайных ошибок.
#
#
# ![image.png](data:image/png;base64,...)
#
# В итоге… Для каждого  справедливы формулы:
#
#
# σ_i=√(X_i )       (a)
# σ_i=X_i         (b)
#
#
# Строим зависимость ошибки от X, если зависимость квадратичная, то берем b, если линейная то a
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
