# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 6.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import gdown
from pathlib import Path

# %%
runs_link = 'https://drive.google.com/file/d/1linmeADE4atW71-2vpqhARR81Z8OcRvn/view?usp=sharing'
output = 'runs.zip'
gdown.download(url=runs_link, output=output, quiet=True, fuzzy=True)
# !unzip runs.zip
# Out:
# Archive:  runs.zip
#    creating: content/runs/detect/val/
#   inflating: content/runs/detect/val/confusion_matrix_normalized.png
#   inflating: content/runs/detect/val/val_batch0_labels.jpg
#   inflating: content/runs/detect/val/confusion_matrix.png
#   inflating: content/runs/detect/val/PR_curve.png
#   inflating: content/runs/detect/val/F1_curve.png
#   inflating: content/runs/detect/val/val_batch2_labels.jpg
#   inflating: content/runs/detect/val/val_batch1_labels.jpg
#   inflating: content/runs/detect/val/val_batch0_pred.jpg
#   inflating: content/runs/detect/val/P_curve.png
#   inflating: content/runs/detect/val/val_batch2_pred.jpg
#   inflating: content/runs/detect/val/val_batch1_pred.jpg
#   inflating: content/runs/detect/val/R_curve.png
#   inflating: content/runs/detect/train/train_batch1982.jpg
# replace content/runs/detect/train/results.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: content/runs/detect/train/results.csv
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_link = 'https://drive.google.com/file/d/1ujK4eUwbRl7SW5yv4Bn16VK2AvF2e72f/view?usp=drive_link'
output = 'urbanhack_additional_unlabelled.zip'
gdown.download(url=dataset_link, output=output, quiet=True, fuzzy=True)
# !unzip urbanhack_additional_unlabelled.zip
# Out:
# Archive:  urbanhack_additional_unlabelled.zip
#    creating: urbanhack_additional_unlabelled/
#   inflating: urbanhack_additional_unlabelled/1424_14_36_12-2023-09-11.jpg
#   inflating: urbanhack_additional_unlabelled/38_04_03_05_672687-2023-09-09_35348.jpg
#   inflating: urbanhack_additional_unlabelled/34_14_12_06_790792-2023-08-31_34369.jpg
#   inflating: urbanhack_additional_unlabelled/44_08_13_25_845255-2023-09-06_35033.jpg
#   inflating: urbanhack_additional_unlabelled/17_14_12_06_790792-2023-08-31_34374.jpg
#   inflating: urbanhack_additional_unlabelled/21_06_10_28_567085-2023-09-06_35009.jpg
#   inflating: urbanhack_additional_unlabelled/27_06_55_23_678600-2023-09-13_35850.jpg
#   inflating: urbanhack_additional_unlabelled/4_04_09_57_227749-2023-09-06_34958.jpg
#   inflating: urbanhack_additional_unlabelled/27_06_03_32_238017-2023-09-09_35380.jpg
#   inflating: urbanhack_additional_unlabelled/34_04_08_11_730336-2023-09-13_35811.jpg
# ...

# %%
path = Path(r"/content/urbanhack_additional_unlabelled")
images = [str(f.absolute()) for f in path.glob("**/*")]

# %%
images.remove('/content/urbanhack_additional_unlabelled/.ipynb_checkpoints')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2d6017301524> in <cell line: 1>()
# ----> 1 images.remove('/content/urbanhack_additional_unlabelled/.ipynb_checkpoints')
#
# ValueError: list.remove(x): x not in list

# %%
#указать путь до весов
# %cd '/content/content/runs/detect/train/weights'
model = YOLO('best.pt')
# Out:
# /content/content/runs/detect/train/weights

# %%
# %cd '/content/'
# Out:
# /content

# %%
#указать conf
confidence = 0.7

for image in images:
  result = model.predict(image, save=True, imgsz=640, conf=confidence, save_txt=True, save_conf=True)
# Out:
# image 1/1 /content/urbanhack_additional_unlabelled/38_10_03_45_068726-2023-09-11_35688.jpg: 384x640 48 emptys, 15 filleds, 2536.3ms
# Speed: 16.9ms preprocess, 2536.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels
#
# image 1/1 /content/urbanhack_additional_unlabelled/4_10_03_25_203921-2023-09-06_35057.jpg: 384x640 9 emptys, 16 filleds, 3762.2ms
# Speed: 2.7ms preprocess, 3762.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 2 labels saved to runs/detect/predict2/labels
#
# image 1/1 /content/urbanhack_additional_unlabelled/46_06_10_28_567085-2023-09-06_34990.jpg: 384x640 98 emptys, 64 filleds, 2786.9ms
# Speed: 3.8ms preprocess, 2786.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 3 labels saved to runs/detect/predict2/labels
#
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r inference_X.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/predict2/ (stored 0%)
#   adding: content/runs/detect/predict2/38_10_03_45_068726-2023-09-11_35688.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/4_10_03_25_203921-2023-09-06_35057.jpg (deflated 10%)
#   adding: content/runs/detect/predict2/46_06_10_28_567085-2023-09-06_34990.jpg (deflated 7%)
#   adding: content/runs/detect/predict2/27_04_03_05_672687-2023-09-09_35354.jpg (deflated 10%)
#   adding: content/runs/detect/predict2/38_14_12_06_790792-2023-08-31_34370.jpg (deflated 4%)
#   adding: content/runs/detect/predict2/17_04_03_14_798024-2023-09-11_35619.jpg (deflated 13%)
#   adding: content/runs/detect/predict2/39_14_12_06_790792-2023-08-31_34395.jpg (deflated 12%)
#   adding: content/runs/detect/predict2/43_08_13_25_845255-2023-09-06_35038.jpg (deflated 6%)
#   adding: content/runs/detect/predict2/24_06_10_28_567085-2023-09-06_35014.jpg (deflated 12%)
# ...
